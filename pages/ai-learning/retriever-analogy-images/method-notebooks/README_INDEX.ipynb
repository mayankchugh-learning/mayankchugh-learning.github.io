# %% [markdown]
# # All 26 Retriever Concept Notebooks
#
# Mapped 1:1 to the [Retriever Analogy Handbook](../retriever-analogy-handbook.html).
#
# - **lab** = runnable Colab practical extracted from the source notebooks
# - **THEORY ONLY** = analogy + mapping + failure modes; no dedicated practical yet
#
# **Suggested path:** `00_basics_concepts.ipynb` → use-case chooser → concept notebook.
#
# | # | Concept | Notebook | Type |
# |---|---------|----------|------|
# | 00 | Basics setup (run first) | [00_basics_concepts.ipynb](00_basics_concepts.ipynb) | lab |
# | 01 | [RAG Pipeline](../retriever-analogy-handbook.html#pipeline) | [01_rag_pipeline_theory.ipynb](01_rag_pipeline_theory.ipynb) | **THEORY ONLY** |
# | 02 | [What a Retriever Is](../retriever-analogy-handbook.html#what-is) | [02_what_is_retriever_theory.ipynb](02_what_is_retriever_theory.ipynb) | **THEORY ONLY** |
# | 03 | [search_type / search_kwargs](../retriever-analogy-handbook.html#knobs) | [03_search_type_kwargs_theory.ipynb](03_search_type_kwargs_theory.ipynb) | **THEORY ONLY** |
# | 04 | [Similarity Metrics](../retriever-analogy-handbook.html#similarity) | [04_similarity_metrics_theory.ipynb](04_similarity_metrics_theory.ipynb) | **THEORY ONLY** |
# | 05 | [Metadata Filtering](../retriever-analogy-handbook.html#metadata) | [05_metadata_filtering.ipynb](05_metadata_filtering.ipynb) | lab |
# | 06 | [Pre- vs Post-filtering](../retriever-analogy-handbook.html#pre-post) | [06_pre_vs_post_filtering_theory.ipynb](06_pre_vs_post_filtering_theory.ipynb) | **THEORY ONLY** |
# | 07 | [Sparse / BM25](../retriever-analogy-handbook.html#sparse) | [01_sparse_bm25.ipynb](01_sparse_bm25.ipynb) | lab |
# | 08 | [Dense Retrieval](../retriever-analogy-handbook.html#dense) | [02_dense_similarity.ipynb](02_dense_similarity.ipynb) | lab |
# | 09 | [Hybrid Retrieval](../retriever-analogy-handbook.html#hybrid) | [06_hybrid_retrieval.ipynb](06_hybrid_retrieval.ipynb) | lab |
# | 10 | [Query Rewriting](../retriever-analogy-handbook.html#rewriting) | [09_query_rewriting.ipynb](09_query_rewriting.ipynb) | lab |
# | 11 | [Query Expansion](../retriever-analogy-handbook.html#expansion) | [10_query_expansion.ipynb](10_query_expansion.ipynb) | lab |
# | 12 | [Query Decomposition](../retriever-analogy-handbook.html#decomposition) | [13_query_decomposition.ipynb](13_query_decomposition.ipynb) | lab |
# | 13 | [HyDE](../retriever-analogy-handbook.html#hyde) | [12_hyde.ipynb](12_hyde.ipynb) | lab |
# | 14 | [Multi-Query](../retriever-analogy-handbook.html#multi-query) | [11_multi_query.ipynb](11_multi_query.ipynb) | lab |
# | 15 | [Parent Document](../retriever-analogy-handbook.html#parent-doc) | [14_parent_document.ipynb](14_parent_document.ipynb) | lab |
# | 16 | [Sentence Window](../retriever-analogy-handbook.html#sentence-window) | [15_sentence_window.ipynb](15_sentence_window.ipynb) | lab |
# | 17 | [Multi-Hop](../retriever-analogy-handbook.html#multi-hop) | [16_multi_hop.ipynb](16_multi_hop.ipynb) | lab |
# | 18 | [Weighted Fusion](../retriever-analogy-handbook.html#weighted-fusion) | [08_weighted_fusion.ipynb](08_weighted_fusion.ipynb) | lab |
# | 19 | [RRF](../retriever-analogy-handbook.html#rrf) | [07_rrf.ipynb](07_rrf.ipynb) | lab |
# | 20 | [MMR](../retriever-analogy-handbook.html#mmr) | [03_mmr.ipynb](03_mmr.ipynb) | lab |
# | 21 | [Reranking](../retriever-analogy-handbook.html#reranking) | [17_reranking.ipynb](17_reranking.ipynb) | lab |
# | 22 | [Bi- vs Cross-encoder](../retriever-analogy-handbook.html#cross-encoder) | [22_bi_vs_cross_encoder_theory.ipynb](22_bi_vs_cross_encoder_theory.ipynb) | **THEORY ONLY** |
# | 23 | [Rank Families](../retriever-analogy-handbook.html#rank-families) | [23_rank_families_theory.ipynb](23_rank_families_theory.ipynb) | **THEORY ONLY** |
# | 24 | [Contextual Compression](../retriever-analogy-handbook.html#compression) | [18_contextual_compression.ipynb](18_contextual_compression.ipynb) | lab |
# | 25 | [Multimodal Retrieval](../retriever-analogy-handbook.html#multimodal) | [25_multimodal_retrieval_theory.ipynb](25_multimodal_retrieval_theory.ipynb) | **THEORY ONLY** |
# | 26 | [Query Routing](../retriever-analogy-handbook.html#routing) | [26_query_routing_theory.ipynb](26_query_routing_theory.ipynb) | **THEORY ONLY** |
# | — | Score-threshold knob lab | [04_score_threshold.ipynb](04_score_threshold.ipynb) | lab (extra) |
#
# ### Source originals
# - [`../retriever.ipynb`](../retriever.ipynb)
# - [`../retriever_advance_colab.ipynb`](../retriever_advance_colab.ipynb)
